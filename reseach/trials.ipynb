# %%
! pip install gdown

# %%
import gdown

# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\tukum\\PYthonvscode\\CV project\\Computer-Vesion-Project-Waste-Detection'

# %%
url = "https://drive.google.com/file/d/1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "data/waste_data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61
# From (redirected): https://drive.google.com/uc?id=1ECfl3dtYyfivY8kYPq7RHUBTjC-2vf61&confirm=t&uuid=feb480ff-f5e6-4ff5-899b-dded86409539
# To: c:\Users\tukum\PYthonvscode\CV project\Computer-Vesion-Project-Waste-Detection\data\waste_data.zip
# 100%|██████████| 40.1M/40.1M [00:07<00:00, 5.10MB/s]
# 'data/waste_data.zip'

# %%
# %pwd
# Out:
# 'c:\\Users\\tukum\\PYthonvscode\\CV project\\Computer-Vesion-Project-Waste-Detection'
